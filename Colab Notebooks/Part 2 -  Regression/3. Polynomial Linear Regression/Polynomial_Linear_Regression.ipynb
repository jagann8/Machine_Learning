# %% [markdown]
# why we calling linear in polynomial linear regression ?. because of its function formula its came from linear regression. so we calling its a polynomial linear regression

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import the dataset

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Part 2 -  Regression/3. Polynomial Linear Regression/Copy of Position_Salaries.csv')
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ## Training the linear regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the polynomial regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree=4)
# -------------------------------
# when degree = 2 => y = b0 + b1 x X1 + b2 x X1^2
# when degree = 4 => y = b0 + b1 x X1 + b2 x X1^2 + b3 x X1^3 + b4 x X1^4
# ------------------------------
X_poly = poly_reg.fit_transform(X)

lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the linear regression results

# %%
plt.scatter(X,y, color='red')
# to draw linear line
plt.plot(X, lin_reg.predict(X),color='blue')
plt.title('Truth or Buff { Linear Regression }')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the polynomial regression results

# %%
plt.scatter(X, y, color='red')
plt.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)),color='blue')
plt.title('True or Buff { Polynomial Regression }')
plt.xlabel('Position label')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the polynomial results ( for higher resolution and smooth curve )

# %%
x_grid = np.arange(min(X),max(X),0.1 )
x_grid = x_grid.reshape(len(x_grid),1)
plt.scatter(X,y,color = 'red')
plt.plot(x_grid,lin_reg_2.predict(poly_reg.fit_transform(x_grid)),color='blue')
plt.title('Truth or Buff ( polynomial regression ) for smooth curve ')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Predicting new result with linear regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting new result with polynomial regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))

# the candidate asked to hr i.e he want $ 160,000.
# now hr is checked by using polynomial regression task finally ww can see that salary was $ 158,862.
# now he decided the candidate was true. lets hire them.
# Out:
# array([158862.45265155])
