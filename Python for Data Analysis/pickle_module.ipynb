# %%
import pickle

# %%
students = {
  'Student1' : {'Name' : 'Alice' , 'Age': 23, 'Grade':'A'},
  'Student2' : {'Name' : 'Bob' , 'Age': 22, 'Grade':'B'},
  'Student3' : {'Name' : 'Cillian' , 'Age': 21, 'Grade':'C'}
}

# %%
type(students)
# Out:
# dict

# %%
with open('student_info.txt', 'w') as data:
  data.write(str(students))

# %%
# now lets try to print out the dictionary and print the data type

with open('student_info.txt', 'r') as f:
  for students in f:
    print(students,'\n')
# Out:
# {'Student1': {'Name': 'Alice', 'Age': 23, 'Grade': 'A'}, 'Student2': {'Name': 'Bob', 'Age': 22, 'Grade': 'B'}, 'Student3': {'Name': 'Cillian', 'Age': 21, 'Grade': 'C'}}

# %%
type(students)
# Out:
# str

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-ff20b7317041> in <cell line: 1>()
# ----> 1 students.items()
#
# AttributeError: 'str' object has no attribute 'items'
