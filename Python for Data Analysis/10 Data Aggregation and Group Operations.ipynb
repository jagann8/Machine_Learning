# %%
# import numpy and pandas library
import numpy as np
import pandas as pd

# %%
# example 1
df=pd.DataFrame({'key1':['a','a',None,'b','b','a',None],
                 'key2':pd.Series([1,2,1,2,1,None,1],dtype='Int64'),
                 'data1':np.random.standard_normal(7),
                 'data2':np.random.standard_normal(7)})
df
# Out:
#    key1  key2     data1     data2
# 0     a     1  0.101491 -0.947322
# 1     a     2 -0.542469  0.480391
# 2  None     1  0.161530  0.710835
# 3     b     2 -0.462209  1.400243
# 4     b     1 -2.177288  0.939067
# 5     a  <NA>  0.898714  1.450438
# 6  None     1  0.323844 -0.901653

# %%
# suppose we want to group by data1 by using key1.
grouped=df['data1'].groupby(df['key1'])
grouped

# %%
# now calcualting the grouped mean
grouped.mean()
# Out:
# key1
# a    0.152579
# b   -1.319748
# Name: data1, dtype: float64

# %%
# when we pass multiple array of lists in group by. Result it should be like hierarchical indexing

means=df['data1'].groupby([df['key1'],df['key2']]).mean()
means
# Out:
# key1  key2
# a     1       0.101491
#       2      -0.542469
# b     1      -2.177288
#       2      -0.462209
# Name: data1, dtype: float64

# %%
# we can convert series into dataframe by using unstack()
means.unstack()
# Out:
# key2         1         2
# key1
# a     0.101491 -0.542469
# b    -2.177288 -0.462209

# %%
# Example 2
# here we have group key value i.e can any length
states=np.array(['OH','CA','CA','OH','OH','CA','OH'])
year=[2005,2005,2006,2005,2006,2005,2006]
df['data1'].groupby([states,year]).mean()
# Out:
# CA  2005    0.178123
#     2006    0.161530
# OH  2005   -0.180359
#     2006   -0.926722
# Name: data1, dtype: float64

# %%
df
# Out:
#    key1  key2     data1     data2
# 0     a     1  0.101491 -0.947322
# 1     a     2 -0.542469  0.480391
# 2  None     1  0.161530  0.710835
# 3     b     2 -0.462209  1.400243
# 4     b     1 -2.177288  0.939067
# 5     a  <NA>  0.898714  1.450438
# 6  None     1  0.323844 -0.901653

# %%
df.groupby([df['key1']]).mean()
# Out:
#       key2     data1     data2
# key1
# a      1.5  0.152579  0.327836
# b      1.5 -1.319748  1.169655

# %%
df.groupby([df['key2']]).mean()
# Out:
# <ipython-input-10-a174065dc6a6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby([df['key2']]).mean()
#          data1     data2
# key2
# 1    -0.397606 -0.049768
# 2    -0.502339  0.940317

# %%
df
# Out:
#    key1  key2     data1     data2
# 0     a     1  0.101491 -0.947322
# 1     a     2 -0.542469  0.480391
# 2  None     1  0.161530  0.710835
# 3     b     2 -0.462209  1.400243
# 4     b     1 -2.177288  0.939067
# 5     a  <NA>  0.898714  1.450438
# 6  None     1  0.323844 -0.901653

# %%
df.groupby([df['key1'],df['key2']]).mean()
# Out:
#               data1     data2
# key1 key2
# a    1     0.101491 -0.947322
#      2    -0.542469  0.480391
# b    1    -2.177288  0.939067
#      2    -0.462209  1.400243

# %%
# group by method use size, which returns series containing group values
df.groupby([df['key1'],df['key2']]).size()
# Out:
# key1  key2
# a     1       1
#       2       1
# b     1       1
#       2       1
# dtype: int64

# %%
# by default group by remove missing values. this behavior can disabled by passing disable dropna=False to groupby
# here in result we get Nan becoz in key1 have one None value. So that it will appear
df.groupby(df['key1'],dropna=False).size()
# Out:
# key1
# a      3
# b      2
# NaN    2
# dtype: int64

# %%
df.groupby([df['key1'],df['key2']],dropna=False).size()
# Out:
# key1  key2
# a     1       1
#       2       1
#       <NA>    1
# b     1       1
#       2       1
# NaN   1       2
# dtype: int64

# %%
# Count is similar to size. but here its counts non null values
df.groupby([df['key1']]).count()
# Out:
#       key2  data1  data2
# key1
# a        2      3      3
# b        2      2      2

# %%
df.groupby([df['key1'],df['key2']]).count()
# Out:
#            data1  data2
# key1 key2
# a    1         1      1
#      2         1      1
# b    1         1      1
#      2         1      1

# %%
# now iterating over the groups
for name,group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1  key2     data1     data2
# 0    a     1  0.101491 -0.947322
# 1    a     2 -0.542469  0.480391
# 5    a  <NA>  0.898714  1.450438
# b
#   key1  key2     data1     data2
# 3    b     2 -0.462209  1.400243
# 4    b     1 -2.177288  0.939067

# %%
# in case of multiple key values, first element in the tuple of key values
for (k1,k2), group in df.groupby(['key1','key2']):
    print((k1,k2))
    print(group)
# Out:
# ('a', 1)
#   key1  key2     data1     data2
# 0    a     1  0.101491 -0.947322
# ('a', 2)
#   key1  key2     data1     data2
# 1    a     2 -0.542469  0.480391
# ('b', 1)
#   key1  key2     data1     data2
# 4    b     1 -2.177288  0.939067
# ('b', 2)
#   key1  key2     data1     data2
# 3    b     2 -0.462209  1.400243

# %%
# dictionary of data pieces at one linear
pieces = { name : group for name , group in df.groupby('key1')}
pieces
# Out:
# {'a':   key1  key2     data1     data2
#  0    a     1  0.101491 -0.947322
#  1    a     2 -0.542469  0.480391
#  5    a  <NA>  0.898714  1.450438,
#  'b':   key1  key2     data1     data2
#  3    b     2 -0.462209  1.400243
#  4    b     1 -2.177288  0.939067}

# %%
# By default groupby groups axis=index, but we can group any other axes, now we tring to group by columns
grouped=df.groupby({'key1':'key','key2':'key','data1':'data','data2':'data'},axis='columns')
grouped

# %%
for group_key, group_value in grouped:
    print(group_key)
    print(group_value)
# Out:
# data
#       data1     data2
# 0  0.101491 -0.947322
# 1 -0.542469  0.480391
# 2  0.161530  0.710835
# 3 -0.462209  1.400243
# 4 -2.177288  0.939067
# 5  0.898714  1.450438
# 6  0.323844 -0.901653
# key
#    key1  key2
# 0     a     1
# 1     a     2
# 2  None     1
# 3     b     2
# 4     b     1
# 5     a  <NA>
# 6  None     1

# %%
# Selecting the column and Subset of columns
# Especially for large datasets. only few columns need to be aggregate. we could wrote so
df.groupby(['key1','key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    1    -0.947322
#      2     0.480391
# b    1     0.939067
#      2     1.400243

# %%
# The object returned by this indexing operation is a grouped DataFrame
# if a list or array is passed, or a grouped Series if only a single column name is passed as a scalar:

s_grouped=df.groupby(['key1','key2'])['data2']
s_grouped.mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.SeriesGroupBy object at 0x78666d8a7fa0>>

# %%
# Grouping the dictionaries and series
people=pd.DataFrame(np.random.standard_normal((5,5)),
                    columns=['a','b','c','d','e'],
                    index=["Joe", "Steve", "Wanda", "Jill", "Trey"])
people
# Out:
#               a         b         c         d         e
# Joe   -0.579078 -0.582390 -0.448283 -1.714845  0.791268
# Steve  0.830021 -0.631467 -1.033214 -0.930032 -0.652973
# Wanda -1.192442 -0.512099 -0.621872 -0.335211 -0.587183
# Jill   0.418741  0.952252  0.048087 -1.459792 -0.363298
# Trey  -2.868655 -0.878728  0.875750 -1.214394 -0.120606

# %%
people.iloc[2:3,[1,2]]=np.nan

# %%
people
# Out:
#               a         b         c         d         e
# Joe   -0.579078 -0.582390 -0.448283 -1.714845  0.791268
# Steve  0.830021 -0.631467 -1.033214 -0.930032 -0.652973
# Wanda -1.192442       NaN       NaN -0.335211 -0.587183
# Jill   0.418741  0.952252  0.048087 -1.459792 -0.363298
# Trey  -2.868655 -0.878728  0.875750 -1.214394 -0.120606

# %%
# Now i have group correspondance of the columns want to sum of columns of the group
mapping={'a':'red','b':'red','c':'blue',
         'd':'blue','e':'red','f':'orange'}

# %% [markdown]
# > Here we need to understand one thing in people dataframe does not have 'f' column
#
# > In mapping dictionary we have 'f' column. In groupby will indentify there is no f column in people dataframe. So groupby will removed f column.
#
# > So far here we saw here dataframe groupby excluded columns. Same functionality for Series also

# %%
by_column=people.groupby(mapping,axis='columns')
by_column.sum()
# Out:
#            blue       red
# Joe   -2.163128 -0.370200
# Steve -1.963246 -0.454419
# Wanda -0.335211 -1.779625
# Jill  -1.411705  1.007695
# Trey  -0.338644 -3.867988

# %%
# same functionality for series also
map_series=pd.Series(mapping)
map_series
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object

# %%
people.groupby(map_series,axis='columns').count()
# Out:
#        blue  red
# Joe       2    3
# Steve     2    3
# Wanda     1    2
# Jill      2    3
# Trey      2    3

# %% [markdown]
# ### Grouping with functions

# %% [markdown]
# > any function can pass as group key will be called once per index value ( one per column value if axis=columns. with return values used as grouped names
#
# > in below we grouping name of the length by passing len function in groupby

# %%
people.groupby(len).sum()
# here we got the index 3,4 and 5. it means name of length jill is 4. so it happens like
# Out:
#           a         b         c         d         e
# 3 -0.579078 -0.582390 -0.448283 -1.714845  0.791268
# 4 -2.449914  0.073524  0.923837 -2.674186 -0.483904
# 5 -0.362421 -0.631467 -1.033214 -1.265243 -1.240155

# %%
people.groupby(len).min()
# Out:
#           a         b         c         d         e
# 3 -0.579078 -0.582390 -0.448283 -1.714845  0.791268
# 4 -2.868655 -0.878728  0.048087 -1.459792 -0.363298
# 5 -1.192442 -0.631467 -1.033214 -0.930032 -0.652973

# %%
# mixing functions with arrays, dictionaries or series not a problem. everything it converts internally as arary
key_list=['one','one','one','two','two']
fg=people.groupby([len,key_list])
fg.min()
# Out:
#               a         b         c         d         e
# 3 one -0.579078 -0.582390 -0.448283 -1.714845  0.791268
# 4 two -2.868655 -0.878728  0.048087 -1.459792 -0.363298
# 5 one -1.192442 -0.631467 -1.033214 -0.930032 -0.652973

# %%
# group by index levels
columns=pd.MultiIndex.from_arrays([['US','US','US','JP','JP'],[1,3,5,1,3]],names=['cty','tenor'])
hie_df=pd.DataFrame(np.random.standard_normal((4,5)),columns=columns)
hie_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0      0.560566  1.325904 -0.478136  0.818658 -0.726797
# 1     -0.801257 -1.000643 -1.616355  0.767901 -1.284202
# 2      0.177474  0.232462 -0.472798 -0.697091 -0.007794
# 3      0.932253  0.408263  0.699889 -0.189825  0.429273

# %%
# we can group by passing level argument
hie_df.groupby(level='cty',axis='columns').count()
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %%
df
# Out:
#    key1  key2     data1     data2
# 0     a     1  0.101491 -0.947322
# 1     a     2 -0.542469  0.480391
# 2  None     1  0.161530  0.710835
# 3     b     2 -0.462209  1.400243
# 4     b     1 -2.177288  0.939067
# 5     a  <NA>  0.898714  1.450438
# 6  None     1  0.323844 -0.901653

# %%
grouped=df.groupby('key1')
grouped['data1'].nsmallest(2)
# Out:
# key1
# a     1   -0.542469
#       0    0.101491
# b     4   -2.177288
#       3   -0.462209
# Name: data1, dtype: float64

# %%
grouped.count()
# Out:
#       key2  data1  data2
# key1
# a        2      3      3
# b        2      2      2

# %%
# passing own aggregate function
def peak_to_peak(arr):
    return arr.max()-arr.min()

grouped.agg(peak_to_peak)
# Out:
#       key2     data1     data2
# key1
# a        1  1.441183  2.397761
# b        1  1.715079  0.461176

# %%
grouped.describe()
# Out:
#       key2                                           data1            ...  \
#      count mean       std  min   25%  50%   75%  max count      mean  ...
# key1                                                                  ...
# a      2.0  1.5  0.707107  1.0  1.25  1.5  1.75  2.0   3.0  0.152579  ...
# b      2.0  1.5  0.707107  1.0  1.25  1.5  1.75  2.0   2.0 -1.319748  ...
#
#                          data2                                          \
#            75%       max count      mean       std       min       25%
# key1
# a     0.500103  0.898714   3.0  0.327836  1.206138 -0.947322 -0.233465
# b    -0.890979 -0.462209   2.0  1.169655  0.326100  0.939067  1.054361
#
#
#            50%       75%       max
# key1
# a     0.480391  0.965415  1.450438
# b     1.169655  1.284949  1.400243
#
# [2 rows x 24 columns]

# %%
# Column wise and Multiple function application
tips=pd.read_csv('/content/drive/MyDrive/Python for Data Analysis/DataSets/tips.csv')
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
tips['tips_pct']=tips['tip'] / tips['total_bill']
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size  tips_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808

# %%
grouped = tips.groupby(['day','smoker'])
grouped_pct=grouped['tips_pct']
grouped_pct.agg('mean')
# Out:
# day   smoker
# Fri   No        0.151650
#       Yes       0.174783
# Sat   No        0.158048
#       Yes       0.147906
# Sun   No        0.160113
#       Yes       0.187250
# Thur  No        0.160298
#       Yes       0.163863
# Name: tips_pct, dtype: float64

# %%
grouped_pct.agg(['mean','std',peak_to_peak])
# Out:
#                  mean       std  peak_to_peak
# day  smoker
# Fri  No      0.151650  0.028123      0.067349
#      Yes     0.174783  0.051293      0.159925
# Sat  No      0.158048  0.039767      0.235193
#      Yes     0.147906  0.061375      0.290095
# Sun  No      0.160113  0.042347      0.193226
#      Yes     0.187250  0.154134      0.644685
# Thur No      0.160298  0.038774      0.193350
#      Yes     0.163863  0.039389      0.151240

# %%
# we can define our own column names by passing tupls like this (name,function)
grouped_pct.agg([('average','mean'),('standard_deviation',np.std)])
# Out:
#               average  standard_deviation
# day  smoker
# Fri  No      0.151650            0.028123
#      Yes     0.174783            0.051293
# Sat  No      0.158048            0.039767
#      Yes     0.147906            0.061375
# Sun  No      0.160113            0.042347
#      Yes     0.187250            0.154134
# Thur No      0.160298            0.038774
#      Yes     0.163863            0.039389

# %%
# with dataframe we have lot options. we can apply list of functions into all columns or
# different functin per column

functions=['count','min','max']
result=grouped[['tips_pct','total_bill']].agg(functions)
result
# Out:
#             tips_pct                     total_bill
#                count       min       max      count    min    max
# day  smoker
# Fri  No            4  0.120385  0.187735          4  12.46  22.75
#      Yes          15  0.103555  0.263480         15   5.75  40.17
# Sat  No           45  0.056797  0.291990         45   7.25  48.33
#      Yes          42  0.035638  0.325733         42   3.07  50.81
# Sun  No           57  0.059447  0.252672         57   8.77  48.17
#      Yes          19  0.065660  0.710345         19   7.25  45.35
# Thur No           45  0.072961  0.266312         45   7.51  41.19
#      Yes          17  0.090014  0.241255         17  10.34  43.11

# %%
result['tips_pct']
# Out:
#              count       min       max
# day  smoker
# Fri  No          4  0.120385  0.187735
#      Yes        15  0.103555  0.263480
# Sat  No         45  0.056797  0.291990
#      Yes        42  0.035638  0.325733
# Sun  No         57  0.059447  0.252672
#      Yes        19  0.065660  0.710345
# Thur No         45  0.072961  0.266312
#      Yes        17  0.090014  0.241255

# %%
# list of tuples with custom column names can be passed
functions=[('average','mean'),('variance',np.var)]
result_2=grouped[['tips_pct','total_bill']].agg(functions)
result_2
# Out:
#              tips_pct           total_bill
#               average  variance    average    variance
# day  smoker
# Fri  No      0.151650  0.000791  18.420000   25.596333
#      Yes     0.174783  0.002631  16.813333   82.562438
# Sat  No      0.158048  0.001581  19.661778   79.908965
#      Yes     0.147906  0.003767  21.276667  101.387535
# Sun  No      0.160113  0.001793  20.506667   66.099980
#      Yes     0.187250  0.023757  24.120000  109.046044
# Thur No      0.160298  0.001503  17.113111   59.625081
#      Yes     0.163863  0.001551  19.190588   69.808518

# %%
# suppose we want to apply diffrent functions into one or more column then we need to pass dictionary to agg functions
grouped.agg({'tip':np.max,'size':'sum'})
# Out:
#                tip  size
# day  smoker
# Fri  No       3.50     9
#      Yes      4.73    31
# Sat  No       9.00   115
#      Yes     10.00   104
# Sun  No       6.00   167
#      Yes      6.50    49
# Thur No       6.70   112
#      Yes      5.00    40

# %% [markdown]
# > DataFrame will hava Hierarchical indexing only if multiple functions are applied atleast one column

# %%
grouped.agg({'tips_pct':['min','max','std','mean'],'size':'sum'})
# Out:
#              tips_pct                               size
#                   min       max       std      mean  sum
# day  smoker
# Fri  No      0.120385  0.187735  0.028123  0.151650    9
#      Yes     0.103555  0.263480  0.051293  0.174783   31
# Sat  No      0.056797  0.291990  0.039767  0.158048  115
#      Yes     0.035638  0.325733  0.061375  0.147906  104
# Sun  No      0.059447  0.252672  0.042347  0.160113  167
#      Yes     0.065660  0.710345  0.154134  0.187250   49
# Thur No      0.072961  0.266312  0.038774  0.160298  112
#      Yes     0.090014  0.241255  0.039389  0.163863   40

# %%
# Returning aggregated data without row indexes
# we can disable row indexes by passing as_index=False

tips.groupby(['day','smoker'],as_index=False).mean()
# Out:
# <ipython-input-52-d880f228060f>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tips.groupby(['day','smoker'],as_index=False).mean()
#     day smoker  total_bill       tip      size  tips_pct
# 0   Fri     No   18.420000  2.812500  2.250000  0.151650
# 1   Fri    Yes   16.813333  2.714000  2.066667  0.174783
# 2   Sat     No   19.661778  3.102889  2.555556  0.158048
# 3   Sat    Yes   21.276667  2.875476  2.476190  0.147906
# 4   Sun     No   20.506667  3.167895  2.929825  0.160113
# 5   Sun    Yes   24.120000  3.516842  2.578947  0.187250
# 6  Thur     No   17.113111  2.673778  2.488889  0.160298
# 7  Thur    Yes   19.190588  3.030000  2.352941  0.163863

# %%
# Apply general split applie combine
# we want to findout top 5 tips percentage
def top(df,n=5,column='tips_pct'):
    return df.sort_values(column,ascending=False)[:n]

top(tips,n=6)
# Out:
#      total_bill   tip smoker  day    time  size  tips_pct
# 172        7.25  5.15    Yes  Sun  Dinner     2  0.710345
# 178        9.60  4.00    Yes  Sun  Dinner     2  0.416667
# 67         3.07  1.00    Yes  Sat  Dinner     1  0.325733
# 232       11.61  3.39     No  Sat  Dinner     2  0.291990
# 183       23.17  6.50    Yes  Sun  Dinner     4  0.280535
# 109       14.31  4.00    Yes  Sat  Dinner     2  0.279525

# %%
tips.groupby('smoker').apply(top)
# Out:
#             total_bill   tip smoker   day    time  size  tips_pct
# smoker
# No     232       11.61  3.39     No   Sat  Dinner     2  0.291990
#        149        7.51  2.00     No  Thur   Lunch     2  0.266312
#        51        10.29  2.60     No   Sun  Dinner     2  0.252672
#        185       20.69  5.00     No   Sun  Dinner     5  0.241663
#        88        24.71  5.85     No  Thur   Lunch     2  0.236746
# Yes    172        7.25  5.15    Yes   Sun  Dinner     2  0.710345
#        178        9.60  4.00    Yes   Sun  Dinner     2  0.416667
#        67         3.07  1.00    Yes   Sat  Dinner     1  0.325733
#        183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
#        109       14.31  4.00    Yes   Sat  Dinner     2  0.279525

# %%
# if we pass a function to apply it takes other arguments or keywords, we can pass the arguments after the function
tips.groupby(['smoker','day']).apply(top,n=5,column='total_bill')
# Out:
#                  total_bill    tip smoker   day    time  size  tips_pct
# smoker day
# No     Fri  94        22.75   3.25     No   Fri  Dinner     2  0.142857
#             91        22.49   3.50     No   Fri  Dinner     2  0.155625
#             223       15.98   3.00     No   Fri   Lunch     3  0.187735
#             99        12.46   1.50     No   Fri  Dinner     2  0.120385
#        Sat  212       48.33   9.00     No   Sat  Dinner     4  0.186220
#             59        48.27   6.73     No   Sat  Dinner     4  0.139424
#             23        39.42   7.58     No   Sat  Dinner     4  0.192288
#             238       35.83   4.67     No   Sat  Dinner     3  0.130338
#             39        31.27   5.00     No   Sat  Dinner     3  0.159898
#        Sun  156       48.17   5.00     No   Sun  Dinner     6  0.103799
#             112       38.07   4.00     No   Sun  Dinner     3  0.105070
#             11        35.26   5.00     No   Sun  Dinner     4  0.141804
#             52        34.81   5.20     No   Sun  Dinner     4  0.149382
#             47        32.40   6.00     No   Sun  Dinner     4  0.185185
#        Thur 142       41.19   5.00     No  Thur   Lunch     5  0.121389
#             85        34.83   5.17     No  Thur   Lunch     4  0.148435
#             141       34.30   6.70     No  Thur   Lunch     6  0.195335
#             125       29.80   4.20     No  Thur   Lunch     6  0.140940
#             77        27.20   4.00     No  Thur   Lunch     4  0.147059
# Yes    Fri  95        40.17   4.73    Yes   Fri  Dinner     4  0.117750
#             90        28.97   3.00    Yes   Fri  Dinner     2  0.103555
#             96        27.28   4.00    Yes   Fri  Dinner     2  0.146628
#             98        21.01   3.00    Yes   Fri  Dinner     2  0.142789
#             93        16.32   4.30    Yes   Fri  Dinner     2  0.263480
#        Sat  170       50.81  10.00    Yes   Sat  Dinner     3  0.196812
#             102       44.30   2.50    Yes   Sat  Dinner     3  0.056433
#             207       38.73   3.00    Yes   Sat  Dinner     4  0.077459
#             56        38.01   3.00    Yes   Sat  Dinner     4  0.078927
#             237       32.83   1.17    Yes   Sat  Dinner     2  0.035638
#        Sun  182       45.35   3.50    Yes   Sun  Dinner     3  0.077178
#             184       40.55   3.00    Yes   Sun  Dinner     2  0.073983
#             180       34.65   3.68    Yes   Sun  Dinner     4  0.106205
#             179       34.63   3.55    Yes   Sun  Dinner     2  0.102512
#             175       32.90   3.11    Yes   Sun  Dinner     2  0.094529
#        Thur 197       43.11   5.00    Yes  Thur   Lunch     4  0.115982
#             83        32.68   5.00    Yes  Thur   Lunch     2  0.152999
#             192       28.44   2.56    Yes  Thur   Lunch     2  0.090014
#             204       20.53   4.00    Yes  Thur   Lunch     4  0.194837
#             191       19.81   4.19    Yes  Thur   Lunch     2  0.211509

# %%
result_3=tips.groupby('smoker')['tips_pct'].describe()
result_3
# Out:
#         count      mean       std       min       25%       50%       75%  \
# smoker
# No      151.0  0.159328  0.039910  0.056797  0.136906  0.155625  0.185014
# Yes      93.0  0.163196  0.085119  0.035638  0.106771  0.153846  0.195059
#
#              max
# smoker
# No      0.291990
# Yes     0.710345

# %%
result_3.unstack('smoker')
# Out:
#        smoker
# count  No        151.000000
#        Yes        93.000000
# mean   No          0.159328
#        Yes         0.163196
# std    No          0.039910
#        Yes         0.085119
# min    No          0.056797
#        Yes         0.035638
# 25%    No          0.136906
#        Yes         0.106771
# 50%    No          0.155625
#        Yes         0.153846
# 75%    No          0.185014
#        Yes         0.195059
# max    No          0.291990
#        Yes         0.710345
# dtype: float64

# %%
# we can disable group keys by passing group_keys=False
tips.groupby('smoker').apply(top)
# Out:
#             total_bill   tip smoker   day    time  size  tips_pct
# smoker
# No     232       11.61  3.39     No   Sat  Dinner     2  0.291990
#        149        7.51  2.00     No  Thur   Lunch     2  0.266312
#        51        10.29  2.60     No   Sun  Dinner     2  0.252672
#        185       20.69  5.00     No   Sun  Dinner     5  0.241663
#        88        24.71  5.85     No  Thur   Lunch     2  0.236746
# Yes    172        7.25  5.15    Yes   Sun  Dinner     2  0.710345
#        178        9.60  4.00    Yes   Sun  Dinner     2  0.416667
#        67         3.07  1.00    Yes   Sat  Dinner     1  0.325733
#        183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
#        109       14.31  4.00    Yes   Sat  Dinner     2  0.279525

# %%
tips.groupby('smoker',group_keys=False).apply(top)
# Out:
#      total_bill   tip smoker   day    time  size  tips_pct
# 232       11.61  3.39     No   Sat  Dinner     2  0.291990
# 149        7.51  2.00     No  Thur   Lunch     2  0.266312
# 51        10.29  2.60     No   Sun  Dinner     2  0.252672
# 185       20.69  5.00     No   Sun  Dinner     5  0.241663
# 88        24.71  5.85     No  Thur   Lunch     2  0.236746
# 172        7.25  5.15    Yes   Sun  Dinner     2  0.710345
# 178        9.60  4.00    Yes   Sun  Dinner     2  0.416667
# 67         3.07  1.00    Yes   Sat  Dinner     1  0.325733
# 183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
# 109       14.31  4.00    Yes   Sat  Dinner     2  0.279525

# %%
# Quantile and bucket analysis
frame=pd.DataFrame({'data1':np.random.standard_normal(1000),
                    'data2':np.random.standard_normal(1000)})
frame.head()
# Out:
#       data1     data2
# 0 -0.219380 -0.109203
# 1 -0.275011  2.629337
# 2 -0.799150  0.406310
# 3 -0.526554  3.196295
# 4 -0.646248 -0.205152

# %%
quartile=pd.cut(frame['data1'],4)
quartile.head(10)
# Out:
# 0    (-1.608, 0.139]
# 1    (-1.608, 0.139]
# 2    (-1.608, 0.139]
# 3    (-1.608, 0.139]
# 4    (-1.608, 0.139]
# 5    (-1.608, 0.139]
# 6     (0.139, 1.886]
# 7     (0.139, 1.886]
# 8    (-1.608, 0.139]
# 9    (-1.608, 0.139]
# Name: data1, dtype: category
# Categories (4, interval[float64, right]): [(-3.362, -1.608] < (-1.608, 0.139] < (0.139, 1.886] <
#                                            (1.886, 3.633]]

# %%
def get_stats(group):
    return pd.DataFrame({'min':group.min(),'max':group.max(),'count':group.count(),'mean':group.mean()})

grouped=frame.groupby(quartile)
grouped.apply(get_stats)
# Out:
#                              min       max  count      mean
# data1
# (-3.362, -1.608] data1 -3.354841 -1.614652     65 -2.022492
#                  data2 -2.043068  2.113929     65 -0.027042
# (-1.608, 0.139]  data1 -1.607639  0.137381    484 -0.572096
#                  data2 -2.481060  3.196295    484  0.038876
# (0.139, 1.886]   data1  0.139612  1.833422    429  0.775245
#                  data2 -2.771532  2.386737    429  0.002223
# (1.886, 3.633]   data1  1.935074  3.633096     22  2.449086
#                  data2 -2.115766  1.800286     22  0.059540

# %%
# same results we can obtain by using this one
grouped.agg(['min','max','count','mean'])
# Out:
#                      data1                               data2            \
#                        min       max count      mean       min       max
# data1
# (-3.362, -1.608] -3.354841 -1.614652    65 -2.022492 -2.043068  2.113929
# (-1.608, 0.139]  -1.607639  0.137381   484 -0.572096 -2.481060  3.196295
# (0.139, 1.886]    0.139612  1.833422   429  0.775245 -2.771532  2.386737
# (1.886, 3.633]    1.935074  3.633096    22  2.449086 -2.115766  1.800286
#
#
#                  count      mean
# data1
# (-3.362, -1.608]    65 -0.027042
# (-1.608, 0.139]    484  0.038876
# (0.139, 1.886]     429  0.002223
# (1.886, 3.633]      22  0.059540

# %%
# now passing labels are false
quartiles_samp=pd.qcut(frame['data1'],4,labels=False)
quartiles_samp.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: data1, dtype: int64

# %%
grouped_samp=frame.groupby(quartiles_samp)
grouped_samp.apply(get_stats)
# Out:
#                   min       max  count      mean
# data1
# 0     data1 -3.354841 -0.708047    250 -1.325233
#       data2 -2.387661  2.750682    250 -0.057557
# 1     data1 -0.693971 -0.001207    250 -0.320023
#       data2 -2.481060  3.196295    250  0.088239
# 2     data1  0.002139  0.671119    250  0.325782
#       data2 -2.440215  3.010258    250  0.080290
# 3     data1  0.671291  3.633096    250  1.231887
#       data2 -2.771532  2.386737    250 -0.033685

# %%
# example
# filling the missing values with group specific values
s=pd.Series(np.random.standard_normal(6))
s[::2]=np.nan
s
# Out:
# 0         NaN
# 1    1.870322
# 2         NaN
# 3   -1.330558
# 4         NaN
# 5   -0.268109
# dtype: float64

# %%
# to find the missing values in s
s.fillna(s.mean())
# Out:
# 0    0.090551
# 1    1.870322
# 2    0.090551
# 3   -1.330558
# 4    0.090551
# 5   -0.268109
# dtype: float64

# %%
states=["Ohio", "New York", "Vermont", "Florida","Oregon", "Nevada", "California", "Idaho"]
group_key=['East','East','East','East','West','West','West','West']
data=pd.Series(np.random.standard_normal(8),index=states)
data
# Out:
# Ohio         -0.993542
# New York      1.131444
# Vermont      -0.122566
# Florida      -1.398699
# Oregon       -0.125564
# Nevada        0.434171
# California    0.522750
# Idaho        -2.173393
# dtype: float64

# %%
# lets set some values are Nan
data[["Vermont", "Nevada", "Idaho"]]=np.nan
data
# Out:
# Ohio         -0.993542
# New York      1.131444
# Vermont            NaN
# Florida      -1.398699
# Oregon       -0.125564
# Nevada             NaN
# California    0.522750
# Idaho              NaN
# dtype: float64

# %%
data.groupby(group_key).size()
# Out:
# East    4
# West    4
# dtype: int64

# %%
data.groupby(group_key).count()
# Out:
# East    3
# West    2
# dtype: int64

# %%
data.groupby(group_key).mean()
# Out:
# East   -0.420266
# West    0.198593
# dtype: float64

# %%
# we can fill the NA values by using group mean
def fill_mean(group):
    return group.fillna(group.mean())

data.groupby(group_key).apply(fill_mean)
# Out:
# <ipython-input-73-29c1a78c42e2>:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data.groupby(group_key).apply(fill_mean)
# Ohio         -0.993542
# New York      1.131444
# Vermont      -0.420266
# Florida      -1.398699
# Oregon       -0.125564
# Nevada        0.198593
# California    0.522750
# Idaho         0.198593
# dtype: float64

# %%
fill_values={'East':0.5,'West':-1}
def fill_func(group):
    return group.fillna(fill_values[group.name])

data.groupby(group_key).apply(fill_func)
# Out:
# <ipython-input-74-34f154e07114>:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data.groupby(group_key).apply(fill_func)
# Ohio         -0.993542
# New York      1.131444
# Vermont       0.500000
# Florida      -1.398699
# Oregon       -0.125564
# Nevada       -1.000000
# California    0.522750
# Idaho        -1.000000
# dtype: float64

# %%
# Example of random sampling and permutations
suits=['H','S','C','D']
card_val=(list(range(1,11))+[10]*3)*4
base_names=["A"]+list(range(2,11))+['J','K','Q']
cards=[]

for suit in suits:
    cards.extend(str(num) + suit for num in base_names)

deck=pd.Series(card_val,index=cards)
deck.head(13)
# Out:
# AH      1
# 2H      2
# 3H      3
# 4H      4
# 5H      5
# 6H      6
# 7H      7
# 8H      8
# 9H      9
# 10H    10
# JH     10
# KH     10
# QH     10
# dtype: int64

# %%
def draw(deck,n=5):
    return deck.sample(n)

draw(deck)
# Out:
# 10S    10
# 2H      2
# 5D      5
# 4H      4
# AH      1
# dtype: int64

# %%
def get_suit(card):
    return card[-1] # getting last suit

deck.groupby(get_suit).apply(draw,n=2)
# Out:
# C  AC      1
#    7C      7
# D  10D    10
#    KD     10
# H  10H    10
#    2H      2
# S  6S      6
#    JS     10
# dtype: int64

# %%
# we can drop outer suit by passing group keys = False
deck.groupby(get_suit,group_keys=False).apply(draw,n=2)
# Out:
# JC    10
# QC    10
# 8D     8
# QD    10
# JH    10
# 6H     6
# 2S     2
# QS    10
# dtype: int64

# %%
# Group weighted average and correaltion
df=pd.DataFrame({'category':['a','a','a','a','b','b','b','b'],
                 'data':np.random.standard_normal(8),
                 'weights':np.random.uniform(size=8)})

df
# Out:
#   category      data   weights
# 0        a -1.331988  0.888668
# 1        a -0.000502  0.214806
# 2        a -0.998305  0.658761
# 3        a -1.629988  0.884380
# 4        b  0.212411  0.558043
# 5        b  0.834895  0.863927
# 6        b -0.383969  0.247344
# 7        b -0.848147  0.476464

# %%
grouped=df.groupby('category')

def get_wavg(group):
    return np.average(group['data'],weights=group['weights'])

grouped.apply(get_wavg)
# Out:
# category
# a   -1.240443
# b    0.158795
# dtype: float64

# %%
# consider another example
close_px=pd.read_csv('/content/drive/MyDrive/Python for Data Analysis/DataSets/stock_px.csv',
                     parse_dates=True,
                     index_col=0)
close_px.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB

# %%
close_px.tail(4)
# Out:
#               AAPL   MSFT    XOM      SPX
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58

# %%
def spx_corr(group):
    return group.corrwith(group['SPX'])

# %%
rets=close_px.pct_change().dropna()

def get_year(x):
    return x.year

by_year=rets.groupby(get_year)
by_year.apply(spx_corr)
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
def corr_aapl_msft(group):
    return group['AAPL'].corr(group['MSFT'])

by_year.apply(corr_aapl_msft)
# Out:
# 2003    0.480868
# 2004    0.259024
# 2005    0.300093
# 2006    0.161735
# 2007    0.417738
# 2008    0.611901
# 2009    0.432738
# 2010    0.571946
# 2011    0.581987
# dtype: float64

# %%
# Group wise linear regression
import statsmodels.api as sm

def regress(data,yvars=None,xvars=None):
    Y=data[yvars]
    X=data[xvars]
    X['intercept']=1
    result=sm.OLS(Y,X).fit()
    return result.params

by_year.apply(regress,xvars=['SPX'],yvars='AAPL')
# Out:
#            SPX  intercept
# 2003  1.195406   0.000710
# 2004  1.363463   0.004201
# 2005  1.766415   0.003246
# 2006  1.645496   0.000080
# 2007  1.198761   0.003438
# 2008  0.968016  -0.001110
# 2009  0.879103   0.002954
# 2010  1.052608   0.001261
# 2011  0.806605   0.001514

# %%
# Grouped transforms and un-wrapped Group Bys

# lets consider simple example for illustartion

df=pd.DataFrame({'key':['a','b','c']*4,
                 'value':np.arange(12.)})
df
# Out:
#    key  value
# 0    a    0.0
# 1    b    1.0
# 2    c    2.0
# 3    a    3.0
# 4    b    4.0
# 5    c    5.0
# 6    a    6.0
# 7    b    7.0
# 8    c    8.0
# 9    a    9.0
# 10   b   10.0
# 11   c   11.0

# %%
g=df.groupby('key')['value']
g.mean()
# Out:
# key
# a    4.5
# b    5.5
# c    6.5
# Name: value, dtype: float64

# %%
# we want to place average value where keys placed to do that we can use transform feature
def get_mean(group):
    return group.mean()

g.transform(get_mean)
# Out:
# 0     4.5
# 1     5.5
# 2     6.5
# 3     4.5
# 4     5.5
# 5     6.5
# 6     4.5
# 7     5.5
# 8     6.5
# 9     4.5
# 10    5.5
# 11    6.5
# Name: value, dtype: float64

# %%
# for aggregate built in functions , we can pass string alias to the agg method
g.transform('mean')
# Out:
# 0     4.5
# 1     5.5
# 2     6.5
# 3     4.5
# 4     5.5
# 5     6.5
# 6     4.5
# 7     5.5
# 8     6.5
# 9     4.5
# 10    5.5
# 11    6.5
# Name: value, dtype: float64

# %%
# apply and transforms returns series of values. but one thing diffrent that is result size is same as input size
# to understand we can create function

def times_two(group):
    return group*2


g.transform(times_two)
# Out:
# 0      0.0
# 1      2.0
# 2      4.0
# 3      6.0
# 4      8.0
# 5     10.0
# 6     12.0
# 7     14.0
# 8     16.0
# 9     18.0
# 10    20.0
# 11    22.0
# Name: value, dtype: float64

# %%
# as more complicated example, we can compute the ranks the desecding order for each group

def get_ranks(group):
    return group.rank(ascending=False)

g.transform(get_ranks)
# Out:
# 0     4.0
# 1     4.0
# 2     4.0
# 3     3.0
# 4     3.0
# 5     3.0
# 6     2.0
# 7     2.0
# 8     2.0
# 9     1.0
# 10    1.0
# 11    1.0
# Name: value, dtype: float64

# %%
# consider a group transformation function composed to from simple aggregations
# in this case we get same results by using either apply or transform
def normalize(x):
    return (x-x.mean())/x.std()

g.transform(normalize)
# Out:
# 0    -1.161895
# 1    -1.161895
# 2    -1.161895
# 3    -0.387298
# 4    -0.387298
# 5    -0.387298
# 6     0.387298
# 7     0.387298
# 8     0.387298
# 9     1.161895
# 10    1.161895
# 11    1.161895
# Name: value, dtype: float64

# %%
g.apply(normalize)
# Out:
# <ipython-input-94-f5e6a374d729>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   g.apply(normalize)
# 0    -1.161895
# 1    -1.161895
# 2    -1.161895
# 3    -0.387298
# 4    -0.387298
# 5    -0.387298
# 6     0.387298
# 7     0.387298
# 8     0.387298
# 9     1.161895
# 10    1.161895
# 11    1.161895
# Name: value, dtype: float64

# %%
# while we using aggregating functions like mean, max, min are much faster than apply function.
# they also have fast pathed when we used transform

g.transform('mean')
# Out:
# 0     4.5
# 1     5.5
# 2     6.5
# 3     4.5
# 4     5.5
# 5     6.5
# 6     4.5
# 7     5.5
# 8     6.5
# 9     4.5
# 10    5.5
# 11    6.5
# Name: value, dtype: float64

# %%
normalized=(df['value']-g.transform('mean'))/g.transform('std')
normalized
# Out:
# 0    -1.161895
# 1    -1.161895
# 2    -1.161895
# 3    -0.387298
# 4    -0.387298
# 5    -0.387298
# 6     0.387298
# 7     0.387298
# 8     0.387298
# 9     1.161895
# 10    1.161895
# 11    1.161895
# Name: value, dtype: float64

# %% [markdown]
# Here, we are doing arithmetic between the outputs of multiple GroupBy operations instead of writing a function and passing it to groupby(...).apply. That is what is meant by “unwrapped.”
#
# While an unwrapped group operation may involve multiple group aggregations, the overall benefit of vectorized operations often outweighs this.

# %%
# Pivot table and cross tabulation
# back to tipping dataset, here we doing pivot table aggregations arranged by day and smoker
# by default pivot table uses mean
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size  tips_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808

# %%
tips.pivot_table(index=['day','smoker'])
# Out:
# <ipython-input-98-ce7f3eb691ce>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   tips.pivot_table(index=['day','smoker'])
#                  size       tip  tips_pct  total_bill
# day  smoker
# Fri  No      2.250000  2.812500  0.151650   18.420000
#      Yes     2.066667  2.714000  0.174783   16.813333
# Sat  No      2.555556  3.102889  0.158048   19.661778
#      Yes     2.476190  2.875476  0.147906   21.276667
# Sun  No      2.929825  3.167895  0.160113   20.506667
#      Yes     2.578947  3.516842  0.187250   24.120000
# Thur No      2.488889  2.673778  0.160298   17.113111
#      Yes     2.352941  3.030000  0.163863   19.190588

# %%
tips.pivot_table(index=['time','day'],columns='smoker',values=['tips_pct','size'])
# Out:
#                  size            tips_pct
# smoker             No       Yes        No       Yes
# time   day
# Dinner Fri   2.000000  2.222222  0.139622  0.165347
#        Sat   2.555556  2.476190  0.158048  0.147906
#        Sun   2.929825  2.578947  0.160113  0.187250
#        Thur  2.000000       NaN  0.159744       NaN
# Lunch  Fri   3.000000  1.833333  0.187735  0.188937
#        Thur  2.500000  2.352941  0.160311  0.163863

# %%
tips.pivot_table(index=['time','day'],columns='smoker',values=['tips_pct','size'],margins=True)
# Out:
#                  size                      tips_pct
# smoker             No       Yes       All        No       Yes       All
# time   day
# Dinner Fri   2.000000  2.222222  2.166667  0.139622  0.165347  0.158916
#        Sat   2.555556  2.476190  2.517241  0.158048  0.147906  0.153152
#        Sun   2.929825  2.578947  2.842105  0.160113  0.187250  0.166897
#        Thur  2.000000       NaN  2.000000  0.159744       NaN  0.159744
# Lunch  Fri   3.000000  1.833333  2.000000  0.187735  0.188937  0.188765
#        Thur  2.500000  2.352941  2.459016  0.160311  0.163863  0.161301
# All          2.668874  2.408602  2.569672  0.159328  0.163196  0.160803

# %%
# if you want aggregates function other than mean. we can use agg func attribute.

tips.pivot_table(index=['time','smoker'],columns='day',values='tips_pct',aggfunc=len,margins=True)
# Out:
# day             Fri   Sat   Sun  Thur  All
# time   smoker
# Dinner No       3.0  45.0  57.0   1.0  106
#        Yes      9.0  42.0  19.0   NaN   70
# Lunch  No       1.0   NaN   NaN  44.0   45
#        Yes      6.0   NaN   NaN  17.0   23
# All            19.0  87.0  76.0  62.0  244

# %%
# in some combinations are empty values or null values. we can pass fill_value=0 or any number that we can pass
tips.pivot_table(index=['size','smoker','time'],columns='day',values='tips_pct',fill_value=0)
# Out:
# day                      Fri       Sat       Sun      Thur
# size smoker time
# 1    No     Dinner  0.000000  0.137931  0.000000  0.000000
#             Lunch   0.000000  0.000000  0.000000  0.181728
#      Yes    Dinner  0.000000  0.325733  0.000000  0.000000
#             Lunch   0.223776  0.000000  0.000000  0.000000
# 2    No     Dinner  0.139622  0.162705  0.168859  0.159744
#             Lunch   0.000000  0.000000  0.000000  0.166005
#      Yes    Dinner  0.171297  0.148668  0.207893  0.000000
#             Lunch   0.181969  0.000000  0.000000  0.158843
# 3    No     Dinner  0.000000  0.154661  0.152663  0.000000
#             Lunch   0.187735  0.000000  0.000000  0.084246
#      Yes    Dinner  0.000000  0.144995  0.152660  0.000000
#             Lunch   0.000000  0.000000  0.000000  0.204952
# 4    No     Dinner  0.000000  0.150096  0.148143  0.000000
#             Lunch   0.000000  0.000000  0.000000  0.138919
#      Yes    Dinner  0.117750  0.124515  0.193370  0.000000
#             Lunch   0.000000  0.000000  0.000000  0.155410
# 5    No     Dinner  0.000000  0.000000  0.206928  0.000000
#             Lunch   0.000000  0.000000  0.000000  0.121389
#      Yes    Dinner  0.000000  0.106572  0.065660  0.000000
# 6    No     Dinner  0.000000  0.000000  0.103799  0.000000
#             Lunch   0.000000  0.000000  0.000000  0.173706

# %%
# cross tabulation ( Cross Tavb )
# cross tabulation is special case in pivot table. that computes group freqencies
# lets look into example to better understand

from io import StringIO

data = """Sample  Nationality  Handedness
    1   USA  Right-handed
    2   Japan    Left-handed
    3   USA  Right-handed
    4   Japan    Right-handed
    5   Japan    Left-handed
    6   Japan    Right-handed
    7   USA  Right-handed
    8   USA  Left-handed
    9   Japan    Right-handed
    10  USA  Right-handed"""

data=pd.read_table(StringIO(data),sep='\s+')
data
# Out:
#    Sample Nationality    Handedness
# 0       1         USA  Right-handed
# 1       2       Japan   Left-handed
# 2       3         USA  Right-handed
# 3       4       Japan  Right-handed
# 4       5       Japan   Left-handed
# 5       6       Japan  Right-handed
# 6       7         USA  Right-handed
# 7       8         USA   Left-handed
# 8       9       Japan  Right-handed
# 9      10         USA  Right-handed

# %%
# we can summarize above table. here we summarizing the nationality and handedness
pd.crosstab(data['Nationality'],data['Handedness'],margins=True)
# Out:
# Handedness   Left-handed  Right-handed  All
# Nationality
# Japan                  2             3    5
# USA                    1             4    5
# All                    3             7   10

# %%
# first two arrguments are crosstab can each be array or series or list of array. As in the tip data
pd.crosstab([tips['time'],tips['day']],tips['smoker'],margins=True)
# Out:
# smoker        No  Yes  All
# time   day
# Dinner Fri     3    9   12
#        Sat    45   42   87
#        Sun    57   19   76
#        Thur    1    0    1
# Lunch  Fri     1    6    7
#        Thur   44   17   61
# All          151   93  244
